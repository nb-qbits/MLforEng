# %%
import os
import sys
from pathlib import Path

# Move from notebooks/ to project root (MLforEng)
project_root = Path("..").resolve()
os.chdir(project_root)

# Make sure project root is on sys.path so `import mlforeng` works
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

print("CWD now:", os.getcwd())

from mlforeng.train import TrainConfig, train
# Out:
# CWD: /Users/vgrover/Downloads/software/AIWorkshops/MLforEng/notebooks
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       1 import os
#       3 print("CWD:", os.getcwd())
# ----> 5 from mlforeng.train import TrainConfig, train
#
# ModuleNotFoundError: No module named 'mlforeng'

# %%
config = TrainConfig(
    model_name="logreg",          # you can change to "rf" later
    n_samples=500,
    n_features=10,
    test_size=0.2,
    save_model_name="nb_logreg_test",
)
config

# %%
results = train(config)
results
